# %%
import pandas as pf

# %%
sales_data = pf.read_csv('sales.csv')

# %%
sales_data.head()
# Out:
#          Date  Product Region  Units Sold  Unit Price  Total Revenue
# 0  2023-02-21    Phone  South         149         387          57663
# 1  2023-04-03   Laptop   East          46         953          43838
# 2  2023-01-15  Monitor  South         169         762         128778
# 3  2023-03-13  Monitor   East          18         738          13284
# 4  2023-03-02  Monitor  North         108         254          27432

# %%
sales_data.isna().sum()
# Out:
# Date             0
# Product          0
# Region           0
# Units Sold       0
# Unit Price       0
# Total Revenue    0
# dtype: int64

# %%
sales_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as md

# %%
issue_data = md.read_csv('sales_data_with_issues.csv')

# %%
issue_data.head()
# Out:
#          Date Region         Category    Sales
# 0  21-06-2023  North        Furniture   575.07
# 1  17-07-2023  North        Furniture  1537.26
# 2  28-07-2023   East       Technology  1543.61
# 3  04-10-2023  South       Technology  1441.21
# 4  07-06-2023   East  Office Supplies  4923.52

# %%
issue_data.isna()
# Out:
#       Date  Region  Category  Sales
# 0    False   False     False  False
# 1    False   False     False  False
# 2    False   False     False  False
# 3    False   False     False  False
# 4    False   False     False  False
# ..     ...     ...       ...    ...
# 200  False   False     False  False
# 201  False   False     False  False
# 202  False   False     False  False
# 203  False   False     False  False
# 204  False   False     False  False
#
# [205 rows x 4 columns]

# %%
issue_data.isna().sum()
# Out:
# Date        0
# Region      3
# Category    0
# Sales       5
# dtype: int64

# %%
issue_data.dropna
# Out:
# <bound method DataFrame.dropna of            Date Region         Category    Sales
# 0    21-06-2023  North        Furniture   575.07
# 1    17-07-2023  North        Furniture  1537.26
# 2    28-07-2023   East       Technology  1543.61
# 3    04-10-2023  South       Technology  1441.21
# 4    07-06-2023   East  Office Supplies  4923.52
# ..          ...    ...              ...      ...
# 200  25-03-2023   West  Office Supplies  1792.31
# 201  14-07-2023   East       Technology  4411.82
# 202  02-04-2023  South       Technology   635.79
# 203  20-07-2023  North        Furniture   673.73
# 204  19-07-2023  South       Technology  1336.89
#
# [205 rows x 4 columns]>

# %%
issue_data.dropna()
# Out:
#            Date Region         Category    Sales
# 0    21-06-2023  North        Furniture   575.07
# 1    17-07-2023  North        Furniture  1537.26
# 2    28-07-2023   East       Technology  1543.61
# 3    04-10-2023  South       Technology  1441.21
# 4    07-06-2023   East  Office Supplies  4923.52
# ..          ...    ...              ...      ...
# 200  25-03-2023   West  Office Supplies  1792.31
# 201  14-07-2023   East       Technology  4411.82
# 202  02-04-2023  South       Technology   635.79
# 203  20-07-2023  North        Furniture   673.73
# 204  19-07-2023  South       Technology  1336.89
#
# [197 rows x 4 columns]

# %%
issue_data.duplicated().sum()
# Out:
# np.int64(5)

# %%
issue_data.drop_duplicates()
# Out:
#            Date Region         Category    Sales
# 0    21-06-2023  North        Furniture   575.07
# 1    17-07-2023  North        Furniture  1537.26
# 2    28-07-2023   East       Technology  1543.61
# 3    04-10-2023  South       Technology  1441.21
# 4    07-06-2023   East  Office Supplies  4923.52
# ..          ...    ...              ...      ...
# 195  24-09-2023  South  Office Supplies  2572.64
# 196  23-02-2023  North  Office Supplies  2785.34
# 197  12-09-2023  South       Technology      NaN
# 198  01-11-2023   West       Technology  3092.66
# 199  29-08-2023  South       Technology      NaN
#
# [200 rows x 4 columns]

# %%
issue_data.duplicated().sum()
# Out:
# np.int64(5)

# %%
issue_data.describe()
# Out:
#              Sales
# count   200.000000
# mean   2558.987250
# std    1333.053941
# min     513.560000
# 25%    1413.180000
# 50%    2550.940000
# 75%    3622.670000
# max    4991.910000

# %%
issue_data.groupby('Region')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
import pandas as vd

# %%
sa_data = vd.read_csv("sales_data_with_issues.csv")

# %%
sa_data.head()
# Out:
#          Date Region         Category    Sales
# 0  21-06-2023  North        Furniture   575.07
# 1  17-07-2023  North        Furniture  1537.26
# 2  28-07-2023   East       Technology  1543.61
# 3  04-10-2023  South       Technology  1441.21
# 4  07-06-2023   East  Office Supplies  4923.52

# %%
sa_data.isna()
# Out:
#       Date  Region  Category  Sales
# 0    False   False     False  False
# 1    False   False     False  False
# 2    False   False     False  False
# 3    False   False     False  False
# 4    False   False     False  False
# ..     ...     ...       ...    ...
# 200  False   False     False  False
# 201  False   False     False  False
# 202  False   False     False  False
# 203  False   False     False  False
# 204  False   False     False  False
#
# [205 rows x 4 columns]

# %%
sa_data.dropna()
# Out:
#            Date Region         Category    Sales
# 0    21-06-2023  North        Furniture   575.07
# 1    17-07-2023  North        Furniture  1537.26
# 2    28-07-2023   East       Technology  1543.61
# 3    04-10-2023  South       Technology  1441.21
# 4    07-06-2023   East  Office Supplies  4923.52
# ..          ...    ...              ...      ...
# 200  25-03-2023   West  Office Supplies  1792.31
# 201  14-07-2023   East       Technology  4411.82
# 202  02-04-2023  South       Technology   635.79
# 203  20-07-2023  North        Furniture   673.73
# 204  19-07-2023  South       Technology  1336.89
#
# [197 rows x 4 columns]

# %%
sa_data.duplicated().sum()
# Out:
# np.int64(5)

# %%
sa_data.drop_duplicates()
# Out:
#            Date Region         Category    Sales
# 0    21-06-2023  North        Furniture   575.07
# 1    17-07-2023  North        Furniture  1537.26
# 2    28-07-2023   East       Technology  1543.61
# 3    04-10-2023  South       Technology  1441.21
# 4    07-06-2023   East  Office Supplies  4923.52
# ..          ...    ...              ...      ...
# 195  24-09-2023  South  Office Supplies  2572.64
# 196  23-02-2023  North  Office Supplies  2785.34
# 197  12-09-2023  South       Technology      NaN
# 198  01-11-2023   West       Technology  3092.66
# 199  29-08-2023  South       Technology      NaN
#
# [200 rows x 4 columns]

# %%
sa_data.describe()
# Out:
#              Sales
# count   200.000000
# mean   2558.987250
# std    1333.053941
# min     513.560000
# 25%    1413.180000
# 50%    2550.940000
# 75%    3622.670000
# max    4991.910000

# %%
sa_data.head(1)
# Out:
#          Date Region   Category   Sales
# 0  21-06-2023  North  Furniture  575.07

# %%
sa_data.groupby("Region")["Sales"].sum()
# Out:
# Region
# East     133186.70
# North    128554.09
# South    117033.54
# West     121530.31
# Name: Sales, dtype: float64

# %%
sa_data.groupby("Region")["Sales"].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
sa_data.head(1)
# Out:
#          Date Region   Category   Sales
# 0  21-06-2023  North  Furniture  575.07

# %%
sa_data.groupby('Region')['Sales'].sum()
# Out:
# Region
# East     133186.70
# North    128554.09
# South    117033.54
# West     121530.31
# Name: Sales, dtype: float64

# %%
sa_data.groupby('Region')['Sales'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='Sales'>
